# %% [markdown]
# <a href="https://colab.research.google.com/github/lsuviz/colab-experiments/blob/main/ZVK_SampleRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ZVK/sampleRNN_ICLR2017.git
# Out:
# Cloning into 'sampleRNN_ICLR2017'...
# remote: Enumerating objects: 604, done.
# remote: Total 604 (delta 0), reused 0 (delta 0), pack-reused 604
# Receiving objects: 100% (604/604), 6.31 MiB | 717.00 KiB/s, done.
# Resolving deltas: 100% (362/362), done.

# %%
# !gdown --id 1-zPGKDV4mKebNYA7DwvUAvPqiB147CTG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-zPGKDV4mKebNYA7DwvUAvPqiB147CTG
# To: /content/chatta.wav
# 331MB [00:04, 72.5MB/s]

# %%
# %cd /content/sampleRNN_ICLR2017/datasets/music/
# Out:
# /content/sampleRNN_ICLR2017/datasets/music

# %%
# !pip2 install scikits.audiolab
# Out:
# ...
#      |████████████████████████████████| 901kB 10.9MB/s
# ...
#   Created wheel for scikits.audiolab: filename=scikits.audiolab-0.11.0-cp27-cp27mu-linux_x86_64.whl size=507117 sha256=f6d67ea533cee2c88bb650526d0b465c41143e361c78570332a532c8528bab2c
#   Stored in directory: /root/.cache/pip/wheels/19/95/78/704c96f15db4fae2d17cdb1e8c48ec0b8ce02369f8d7139285
# Successfully built scikits.audiolab
# ...

# %%
# !python2 new_experiment32k.py chatta downloads/
# Out:
# Streaming output truncated to the last 5000 lines.
# Press [q] to stop, [?] for help
# Output #0, flac, to '/content/sampleRNN_ICLR2017/datasets/music/chatta/parts/p3027.flac':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Audio: flac, 32000 Hz, mono, s16, 16 kb/s
#     Metadata:
#       encoder         : Lavc57.107.100 flac
# size=     303kB time=00:00:08.00 bitrate= 310.0kbits/s speed= 442x
# video:0kB audio:295kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.746790%
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# %cd ../../
# Out:
# /content/sampleRNN_ICLR2017

# %%
# !pwd
# Out:
# /content/sampleRNN_ICLR2017

# %%
# !pip2 install --upgrade https://github.com/Lasagne/Lasagne/archive/master.zip
# Out:
# ...
#      - 378kB 6.0MB/s
# ...
#   Created wheel for Lasagne: filename=Lasagne-0.2.dev1-cp27-none-any.whl size=122797 sha256=a60eb368d909dbb2e8b1fc15c3855f526ab3beeb48d3fb17a97a24915ee42d97
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8vUdmP/wheels/ca/4a/00/87f1777b229481fe76562df7c0cfb993bc88ed0cc37e3f0ed4
# Successfully built Lasagne
# ...

# %%
# !pip2 install pygpu
# Out:
# ERROR: Could not find a version that satisfies the requirement pygpu (from versions: none)
# ERROR: No matching distribution found for pygpu

# %%
# !THEANO_FLAGS=mode=FAST_RUN,device=cuda*,floatX=float32 python2 -u /content/sampleRNN_ICLR2017/models/two_tier/two_tier32k.py --exp BEST_2TIER --n_frames 64 --frame_size 16 --emb_size 256 --skip_conn False --dim 1024 --n_rnn 3 --rnn_type GRU --q_levels 256 --q_type linear --batch_size 64 --weight_norm True --learn_h0 True --which_set chatta
# Out:
# Experiment started at: 2021-02-03 18:27
# ERROR (theano.gpuarray): pygpu was configured but could not be imported or is too old (version 0.7 or higher required)
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/theano/gpuarray/__init__.py", line 23, in <module>
#     import pygpu
# ImportError: No module named pygpu
# Created experiment tag for these args:
# -content-sampleRNN_ICLR2017-models-two_tier-two_tier32k.py-expBEST_2TIER-n_frames64-frame_size16-emb_size256-skip_connF-dim1024-n_rnn3-rnn_typeGRU-q_levels256-q_typelinear-batch_size64-weight_normT-learn_h0T-which_setchatta-lr0.001
# Python:
# 	sys.version_info	sys.version_info(major=2, minor=7, micro=17, releaselevel='final', serial=0)
# Numpy:
# 	.__version__	1.16.4
# Theano:
# 	.__version__	1.0.4
#
#
# All passed args:
# ...
